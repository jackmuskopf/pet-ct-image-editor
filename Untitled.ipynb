# %%
import matplotlib.pyplot as plt
from src.appclasses.dependencies import *
import time
import traceback

# Functions
def get_mat(img):
    if img.img_data is None:
        img.tempdir = tempfile.mkdtemp()
        img.load_image()
    collapse = 'sum' if is_pet(img.filepath) else 'max'
    mat = getattr(img.collapse_over_frames(collapse),collapse)(axis=0)
    return normalize(mat)


def get_files(folder):
    
    fnames = [os.path.join(dp, f) for dp, dn, filenames in os.walk(folder) for f in filenames]
    pet_files =  [PETImage(f) for f in fnames if is_pet(f)]
    ct_files = [CTImage(f) for f in fnames if f.endswith('.ct.img')]
    all_files = pet_files+ct_files
    all_files.sort(key=lambda x: x.subject_id)
    groups = defaultdict(list)
    for img in all_files:
        groups[img.subject_id].append(img)
    img_pairs = groups.values()
    return (ct_files,pet_files)

def rmdir(mydir):
	try:
		shutil.rmtree(mydir)
		print('removing tempdir {}'.format(mydir))
	except Exception as e:
		print(e)
		print('error when removing: \n{}'.format(mydir))


def do_plot(mat,title=''):
	fig = plt.figure()
	ax = fig.add_subplot(111)
	ax.imshow(mat,cmap="gray",clim=(0,1))
	ax.set_title(title)
	ax.set_xlim(0,mat.shape[1])
	ax.set_ylim(0,mat.shape[0])
	return ax


def add_lines(ax,lines):
	'''
	lines is list of tuples, each containing 2 tuples x1,y1; x2,y2
	'''
	for line in lines:
		p1,p2 = line
		x1,y1 = p1
		x2,y2 = p2
		ax.plot([x1,x2],[y1,y2],'r-')


def not_zero(val):
	return abs(val)>10**-100

def normalize(nparray):
    nparray = nparray + abs(nparray.min())
    max_val = nparray.max()
    if not_zero(max_val):
        return nparray/max_val
    else:
        return nparray

    
def get_disk_points(p,r):

    x,y = p[0],p[1]
    xmi,xma = x-r,x+r
    ymi,yma = y-r,y+r
    square = [(int(xi),int(yi)) for xi in np.arange(xmi,xma+1) for yi in np.arange(ymi,yma+1) if (yi>0 and xi>0)]
    circle = [k for k in square if np.sqrt( (x-k[0])**2 + (y-k[1])**2 ) < r]
    return list(set(circle))


def second_deriv(xs,ys):
    '''
    assumes evenly spaced xaxis
    '''
    dx = xs[1]-xs[0]
    dydx = [(ys[i+1]-ys[i])/dx for i in range(len(ys)-1)]
    d2ydx2 = [(dydx[i+1]-dydx[i])/dx for i in range(len(dydx)-1)]
    print(d2ydx2)
    xdp = xs[1:-1]
    return (xdp,d2ydx2)

def find_slope(xvals,yvals,slope):
    dx = xvals[1]-xvals[0]
    dydx = [(yvals[i+1]-yvals[i])/dx for i in range(len(yvals)-1)]
    df1 = [abs(slope-dy) for dy in dydx]
    ix = df1.index(min(df1))
    return ix

def find_cutoff(xvals, yvals, alpha=1, beta=.5, chi=1):
    '''
    max pt to left, min integral to right of pt
    alpha in (0,inf)
    beta in (0,1)
    as beta -> 1, x -> xmax
    as beta -> 0, x -> xmin
    '''
    
    dx = xvals[1]-xvals[0]
    dydx = np.array([(yvals[i+1]-yvals[i])/dx for i in range(len(yvals)-1)])
    slope = dydx.max()
    
    # objective fn1 closeness to origin
    obj1 = np.flip(np.arange(0,len(yvals)-1),axis=0)
    
    # objective fn2 integral from 0 to x*
    obj2 = np.array([sum(yvals[0:k]) for k in range(len(yvals)-1)])
    
    vfa = np.vectorize(lambda x:x**alpha)
    vfc = np.vectorize(lambda x:x**chi)
    myf = beta*vfa(normalize(obj1))+(1-beta)*vfc(normalize(obj2))
    return np.argmin(myf)


def find_mice(binary_mat, img_type):
    
    # allow x percent of image dimensions gap between pixels still same mouse
    
    gap_percent = .05 if img_type == 'pet' else .02
    
    # minimum number of pixels to count as mice (as percentage of total pixels)
    min_mouse_percent = .01
    
    def get_interior(points,mr):
        new_points = []
        for pt in points:
            dpts = get_disk_points(pt,mr)
            ppts = [p for p in points if p in dpts]
            lik = len(ppts)/len(dpts)
            if lik > .3:
                new_points.append(pt)
        return new_points
            
    
    def is_disk(points):
        

        
        yvals, xvals = zip(*points)
        center = (round(np.mean(yvals)),round(np.mean(xvals)))
        max_dist = 0
        
        for pt in points:
            d = np.sqrt((center[0]-pt[0])**2+(center[1]-pt[1])**2)
            max_dist = round(d) if d > max_dist else max_dist
        
        disk_pts = get_disk_points(center,max_dist)
        
        diskishness = len(points)/len(disk_pts)
        print("is_disk: {}".format(diskishness))
        return diskishness > .1
        

    def add_pts(p):
        # print('len open_list: {}; len mouse_open: {}; nmice: {}'.format(len(open_list),len(mouse_open_list),len(mouses)))
        y,x=p
        pts = []
        [pts.append(hkp) for j in range(adj_max) for hkp in [
                                                                (y+j,x),
                                                                (y-j,x),
                                                                (y,x+j),
                                                                (y,x-j)
                                                            ]]

        pts = [k for k in pts if k in open_list]

        for k in pts:
            open_list.remove(k)

        for k in pts:
            ty,tx = k
            mouse_open_list.append(k)


    bmat = binary_mat
    s= bmat.shape
    avgdim = (s[0]+s[1])/2
    adj_max = max([1,math.floor(gap_percent*avgdim)])
    interior_test_radius = max([round(np.sqrt(s[0]*s[1])/10),1])
    
    open_list = [(y,x) for x in range(s[1]) for y in range(s[0]) if bmat[y,x]]
    open_list = get_interior(open_list,interior_test_radius)
    cur_mouse = []
    mouses = []

    while open_list:
        tp = open_list.pop(0)
        y,x = tp

        mouse_open_list = [tp,]

        while mouse_open_list:
            mp = mouse_open_list.pop(0)
            cur_mouse.append(mp)
            add_pts(mp)


        min_mouse_size = math.floor(s[0]*s[1]*min_mouse_percent)
        if len(cur_mouse) > min_mouse_size:
            mouses.append(cur_mouse)
        cur_mouse = []
        
        
    mouses = [m for m in mouses if m]

    return mouses #[m for m in mouses if is_disk(m)]
                   
                   

def get_mass(mat,percents):
    
    flt = mat.flatten()
    flt.sort()
    total_mass = flt.sum()
    N = len(flt)
    
    percents = np.array(percents)
    percents.sort()
    
    if not (percents.min()>0 and percents.max()<1):
        raise ValueError('Bad percent input in get_mass')
    
    _ = []
    i=1
    results = []
    for per_mass in percents:
        while sum(_)/total_mass < per_mass:
            _.append(flt[-i])
            i+=1
        npix = len(_)
        per_pix = npix/N
        results.append((per_mass,per_pix))
    return results


# get files
folder = r"C:\Users\jmusko01\Documents\mycode\old_preproc_work\data"
# folder = r"D:\image_data"
ct_imgs, pet_imgs = get_files(folder)

# %%
# histogram stuff

escale = 2.0

for i in range(len(pet_imgs)):
    pimg = pet_imgs[i]
    pimg.tempdir = tempfile.mkdtemp()
    if pimg.img_data is None:
        pimg.load_image()
    mat = pimg.collapse_over_frames('sum').sum(axis=0)
    d = normalize(mat)
    f = d.flatten()
    cutoff = np.percentile(f,93)
    print('Cutoff = {}'.format(cutoff))
    
    tf = lambda x: int(x>cutoff)
    vf = np.vectorize(tf)
    tmat = vf(mat)

    fig = plt.figure()
    hax = fig.add_subplot(131)
    hax.hist(f,bins=40)
    hax.set_ylim(0,1000)
    iax = fig.add_subplot(132)
    iax.imshow(mat,clim=(0,1),cmap='gray')
    iax2 = fig.add_subplot(133)
    iax2.imshow(tmat,clim=(0,1),cmap='gray')
    plt.show()
    clean_up_img(pimg)

# %%
# show image
img = pet_imgs[4]
img.tempdir = tempfile.mkdtemp()
if img.img_data is None:
    img.load_image()
mat = img.collapse_over_frames('sum').sum(axis=0)
fig = plt.figure()
iax = fig.add_subplot(132)
iax.imshow(mat,clim=(0,1),cmap='gray')
plt.show()

# %%
img = pet_imgs[0]
img.load_image()
img.unload_image()
# Out:
# File dimensions: (128,128,95,1)
# Reading image data...

# %%
# for img in ct_imgs[3:]:
for img in pet_imgs:
    a = 5
    b = .5

## pet settings 1
#     alpha=1
#     beta=.65

## pet settings 1
#     alpha=1
#     beta=.72

## pet settings 1
#     alpha=1.1
#     beta=.8, .74  (1.4,.87)

## pet settings 1
#     alpha=1.2
#     beta=.82

## pet best: (.9,.65)


    loaded = True
    try:
        tmat = get_mat(img)
        img.unload_image()
    except KeyboardInterrupt:
        img.unload_image()
        raise KeyboardInterrupt('Interrupted')
    except Exception as e:
        print(e)
        loaded=False


    if loaded:
        dsres = tmat.copy()

        ds = 1
        while dsres.size > 17000:
            ds = ds*2
            dsres = dsres[::2,::2]

        percents = np.arange(1,100)*.01
        results = [(0,0)]+get_mass(dsres,percents)+[(1.0,1.0)]  # add 0,0 and 1,1 since we know these pts exist
        txvals,tyvals = zip(*results)
        
        if img.type == 'pet':
            alpha,beta = (.9,.65)
        else:
            alpha,beta = (5,.5)
        
        slope = 1#*(tyvals[-1]-tyvals[0])/(txvals[-1]-txvals[0])
        ix = find_cutoff(txvals,tyvals, alpha=alpha,beta=beta)
        ycut = (tyvals[ix]+tyvals[ix+1])/2
        xcut = (txvals[ix]+txvals[ix+1])/2
        xcut,ycut = [round(it,4) for it in (xcut,ycut)]
        plt.plot(txvals,tyvals,'b')
        _vals = np.arange(min(tyvals),max(tyvals),.01)
        plt.plot([xcut for x in _vals],_vals,'r')
        plt.title('alpha: {}, beta: {}'.format(round(alpha,2),round(beta,2)))
        plt.ylabel('Percent of pixels needed')
        plt.xlabel('Percent of mass attained')
        plt.show()

        cutoff_percent = (1-ycut)*100

        flt = tmat.flatten()
        cutoff_value = np.percentile(flt,cutoff_percent)

        tf = lambda x: int(x>cutoff_value)
        vf = np.vectorize(tf)
        binary_mat = vf(tmat)
        ds_bmat = vf(dsres)
        mice = find_mice(ds_bmat,img.type)
        nmice = len(mice)

        fig = plt.figure()
        iax = fig.add_subplot(121)
        iax.imshow(tmat*14,clim=(0,1),cmap='gray')
        iax2 = fig.add_subplot(122)
        iax2.imshow(binary_mat,clim=(0,1),cmap='gray')

        for mouse in mice:
            for (y,x) in mouse:
                iax.plot(x*ds,y*ds,'r.')

        print('Found {} mice'.format(nmice))

        plt.show()
# Out:
# File dimensions: (128,128,95,1)
# Reading image data...
# Found 1 mice
# File dimensions: (128,128,95,3)
# Reading image data...
# Found 1 mice
# File dimensions: (128,128,95,40)
# Reading image data...
# Found 2 mice
# File dimensions: (128,128,95,1)
# Reading image data...
# Found 2 mice
# File dimensions: (128,128,95,40)
# Reading image data...
# Found 4 mice
# File dimensions: (128,128,95,1)
# Reading image data...
# Found 2 mice
# File dimensions: (128,128,159,40)
# Reading image data...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-f319a05ece64> in <module>()
#      27     try:
# ---> 28         tmat = get_mat(img)
#      29         img.unload_image()
#
# <ipython-input-17-98aacc7abfb3> in get_mat(img)
#       9         img.tempdir = tempfile.mkdtemp()
# ---> 10         img.load_image()
#      11     collapse = 'sum' if is_pet(img.filepath) else 'max'
#
# ~\Documents\mycode\preprocessing\src\imgclasses\baseimage.py in load_image(self, plane_range, frame_range, unscaled)
#     326             img_file.seek(bpp*(fr_offset+pl_offset))
# --> 327             read_chunks(ifr)
#     328         imgmat = imgmat.swapaxes(0,1)
#
# ~\Documents\mycode\preprocessing\src\imgclasses\baseimage.py in read_chunks(ifr)
#     195                 npixels = int(nbytes/bpp)
# --> 196                 chunk = np.array(struct.unpack(sf*npixels,img_file.read(nbytes)))
#     197                 imgmat[ifr][ix:ix+npixels] = chunk
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# <ipython-input-18-f319a05ece64> in <module>()
#      29         img.unload_image()
#      30     except KeyboardInterrupt:
# ---> 31         img.unload_image()
#      32         raise KeyboardInterrupt('Interrupted')
#      33     except Exception as e:
#
# ~\Documents\mycode\preprocessing\src\imgclasses\baseimage.py in unload_image(self)
#     503         gc.collect()
#     504         if self.tempdir:
# --> 505             shutil.rmtree(self.tempdir)
#     506         self.tempdir = None
#     507
#
# ~\AppData\Local\Continuum\anaconda3\lib\shutil.py in rmtree(path, ignore_errors, onerror)
#     492             os.close(fd)
#     493     else:
# --> 494         return _rmtree_unsafe(path, onerror)
#     495
#     496 # Allow introspection of whether or not the hardening against symlink
#
# ~\AppData\Local\Continuum\anaconda3\lib\shutil.py in _rmtree_unsafe(path, onerror)
#     387                 os.unlink(fullname)
#     388             except OSError:
# --> 389                 onerror(os.unlink, fullname, sys.exc_info())
#     390     try:
#     391         os.rmdir(path)
#
# ~\AppData\Local\Continuum\anaconda3\lib\shutil.py in _rmtree_unsafe(path, onerror)
#     385         else:
#     386             try:
# --> 387                 os.unlink(fullname)
#     388             except OSError:
#     389                 onerror(os.unlink, fullname, sys.exc_info())
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\jmusko01\\AppData\\Local\\Temp\\tmpxj8aw1ev\\mpet3630b_em1_v1.dat'

# %%
### ALGO PARAMS

# bottom x percent of pixels are used for finding gaussian params for no mice
default_cutoff = .9
get_intensity_cutoff = lambda nmice: 1-.035*nmice  # assume mice takes up 3.5% of image



# minimum number of pixels to count as mice (as percentage of total pixels)
min_mouse_percent = .02

# hypothesis test threshold
gamma = .1

# expected mouse percent of image
mouse_percent = .035

# %%
def likelihood_point(xp,h1,h0):


    # hypothesis vars
    mu0,var0 = h0
    mu1,var1 = h1
    # var0 = .0015
    # var1 = .014
    # mu0 = .01
    # mu1 = .29

    like = (var0/var1)*np.exp( (-.5/var1)*(xp-mu1)**2 + (.5/var0)*(xp-mu0)**2 )

    return like







def find_mice(binary_mat):
    
    # allow x percent of image dimensions gap between pixels still same mouse
    gap_percent = .05
    
    # minimum number of pixels to count as mice (as percentage of total pixels)
    min_mouse_percent = .02

    def add_pts(p):
        # print('len open_list: {}; len mouse_open: {}; nmice: {}'.format(len(open_list),len(mouse_open_list),len(mouses)))
        y,x=p
        pts = []
        [pts.append(hkp) for j in range(adj_max) for hkp in [
                                                                (y+j,x),
                                                                (y-j,x),
                                                                (y,x+j),
                                                                (y,x-j)
                                                            ]]

        pts = [k for k in pts if k in open_list]

        for k in pts:
            open_list.remove(k)

        for k in pts:
            ty,tx = k
            if bmat[ty,tx]:
                mouse_open_list.append(k)


    bmat = binary_mat
    s= bmat.shape
    avgdim = (s[0]+s[1])/2
    adj_max = max([1,math.floor(gap_percent*avgdim)])
    open_list = [(y,x) for x in range(s[1]) for y in range(s[0])]
    cur_mouse = []
    mouses = []

    while open_list:
        tp = open_list.pop(0)
        y,x = tp

        mouse_open_list = [tp,] if bmat[tp[0],tp[1]] else []

        while mouse_open_list:
            mp = mouse_open_list.pop(0)
            cur_mouse.append(mp)
            add_pts(mp)


        min_mouse_size = math.floor(s[0]*s[1]*min_mouse_percent)
        if len(cur_mouse) > min_mouse_size:
            mouses.append(cur_mouse)
        cur_mouse = []

    return mouses




def analyze_image(img, nmice=0):


	if nmice == 0:
		intensity_cutoff = default_cutoff
	else:
		intensity_cutoff = get_intensity_cutoff(nmice)

	try:

		print('Analyzing image: {}'.format(img.filepath))
		time.sleep(1)


		# image
		img.tempdir = tempfile.mkdtemp()
		print(img.tempdir)
		if img.img_data is None:
			img.load_image()

		# sum over time axis
		show_method = 'sum' if  is_pet(img.filepath) else 'max'
		frame = img.collapse_over_frames(method='sum')
		show_frame = img.collapse_over_frames(method=show_method)


		# collapse on z axis
		axis = img.get_axis('z')
		mat = getattr(frame, show_method)(axis=axis)
		mat = normalize(mat)
		show_mat = getattr(show_frame, show_method)(axis=axis)
		show_mat = normalize(show_mat)
		
		# get hypothesis vars
		# assume mice compose top 10 %
		
		flt = mat.flatten()
		cutoff = np.percentile(flt,intensity_cutoff*100)

		mouse_pix = np.array([k for k in flt if k > cutoff])
		nothing_pix = np.array([k for k in flt if k < cutoff])

		h0 = nothing_pix.mean(), nothing_pix.std()**2
		h1 = mouse_pix.mean(), mouse_pix.std()**2


	

		gammas = [gamma,]
		for g in gammas:

			# hypothesis test each point is it a mouse?
			tf1 = lambda x: int(likelihood_point(x,h1=h1,h0=h0)>g)
			vf1 = np.vectorize(tf1)
			testmat1 = vf1(mat)
			res = vf1(mat)

			
			### quicker and possibly equivalent way of doing this but I like the proper hypothesis test			
			# tf2 = lambda x: int(x>cutoff)
			# vf2 = np.vectorize(tf2)
			# testmat2 = vf2(mat)
			# tflt1 = testmat1.flatten()
			# tflt2 = testmat2.flatten()
			# tr = [tflt1[i]==tflt2[i] for i in range(len(tflt1))]
			# print('\n'*5,'percent same: {}'.format(len(tr)/float(len(tflt1))),'\n'*5)

			
			# downsample to size ok for group finding algo
			dsres = res.copy()
			ds = 1
			while dsres.size > 15000:
				ds = ds*2
				dsres = dsres[::2,::2]

			mouses = find_mice(dsres)
			mouses = [np.matrix(m)*ds for m in mouses]
			coords = [m.mean(axis=0) for m in mouses]
			for c in coords:
				print('mouse at {}'.format(c))
			print('Found {} mice'.format(len(mouses)))

## bad line; could switch between two results forever
# 			if not (nmice == len(mouses)):
# 				return analyze_image(img,nmice=len(mouses))


			ax = do_plot(show_mat*10,title='original')

			# plot dots over mouse
			for m in mouses:
				for k in range(m.shape[0]):
					y,x = m[k,:][0,0],m[k,:][0,1]
					ax.plot(x,y,'r.')

			lines = []
			for m in mouses:
				my,mx = m.max(axis=0)[0,0],m.max(axis=0)[0,1]
				miy,mix = m.min(axis=0)[0,0],m.min(axis=0)[0,1]
				lines += [[(mix,miy),(mix,my)],[(mix,miy),(mx,miy)],[(mx,my),(mix,my)],[(mx,my),(mx,miy)]]

			add_lines(ax,lines)

			block = (g is gammas[-1])
			# do_plot(res,title='gamma = {}'.format(g),block=block)
			plt.show()
			# plt.draw()

			clean_up_img(img)

			return mouses



	except Exception as e:
		clean_up_img(img)
		print(e)



def clean_up_img(img):
	img.img_data = None
	gc.collect()	
	rmdir(img.tempdir)




def get_radius(x,y,percent_img):
	return np.sqrt(percent_img*x*y/np.pi)

def get_circle_points(p,r):
    
	x,y = p[0],p[1]
	xmi,xma = x-r,x+r
	ymi,yma = y-r,y+r
	square = [(int(xi),int(yi)) for xi in np.arange(xmi,xma+1) for yi in np.arange(ymi,yma+1) if (yi>0 and xi>0)]
	circle = [k for k in square if np.sqrt( (x-k[0])**2 + (y-k[1])**2 ) < r]
	return list(set(circle))


def circle_algo(img):
    
    def circle_test(tp, mat, h0, h1, gamma):
        shp = mat.shape
        
        # test over radius fraction of mouse radius
        mouse_radius = get_radius(x=shp[0],y=shp[1],percent_img=mouse_percent)
        test_radius = mouse_radius*(.1)
        
        test_set = get_circle_points(tp,test_radius)
        test_set = [p for p in test_set if p[1]<shp[0] and p[0]<shp[1]]
        
        mu0,var0 = h0
        mu1,var1 = h1
        
        N = len(test_set)
        
        test_fn = lambda x,y: (1/var1)*(mat[x,y]-mu1)**2 - (1/var0)*(mat[x,y]-mu0)**2
        test_stat = sum([test_fn(p[0],p[1]) for p in test_set])
        
        gamma_prime = -2*np.log(gamma*(var0/var1)**(N/2))
#         print("gp: ",gamma_prime)
#         print("test_stat:",test_stat)
        
        like_ratio = (var0/var1)**(N/2)*np.exp(-(.5)*test_stat)
#         print("(var0/var1)**(N/2):{}\n".format((var0/var1)**(N/2)),"test_stat: {}\n".format(test_stat),
#               "like_ratio: {}\n".format(like_ratio),"gamma: {}\n".format(gamma),"gamma_prime: {}\n".format(gamma_prime))
        
#         return int(like_ratio > gamma)
        return int(test_stat < gamma_prime)

    
    
    intensity_cutoff = .99

    try:

#         print('Analyzing image: {}'.format(img.filepath))
        time.sleep(1)


        # image
        img.tempdir = tempfile.mkdtemp()
        if img.img_data is None:
            img.load_image()
            
        print('Done loading...')

        # sum over time axis
        show_method = 'sum' if  is_pet(img.filepath) else 'max'
        frame = img.collapse_over_frames(method=show_method)
        show_frame = img.collapse_over_frames(method=show_method)


        # collapse on z axis
        axis = img.get_axis('z')
        mat = getattr(frame, show_method)(axis=axis)
        mat = normalize(mat)
        show_mat = getattr(show_frame, show_method)(axis=axis)
        show_mat = normalize(show_mat)*4
        
        orig_mat = mat.copy()
        ds = 1
        while mat.size > 16500:
            ds = ds*2
            mat = mat[::2,::2]

        # get hypothesis vars
        # assume mice compose top 10 %
        flt = mat.flatten()
        ic = (1-abs(mat.mean()))**.5
        print("using cutoff: {}".format(ic))
        cutoff = np.percentile(flt,ic*100)
        mouse_pix = np.array([k for k in flt if k > cutoff])
        nothing_pix = np.array([k for k in flt if k < cutoff])
        


        h0 = nothing_pix.mean(), nothing_pix.std()**2
        h1 = mouse_pix.mean(), mouse_pix.std()**2
        mu0,var0 = h0
        mu1,var1 = h1
        
        print(h1,h0)
        print(mat.mean(),mat.std())
        
         
        res_mat = np.zeros(mat.shape)
        for g in [1]:
            this_fn = lambda p: circle_test(p, mat, h0, h1, g)
            for index, x in np.ndenumerate(mat):
                res_mat[index] = this_fn(index)
            
#             print("max:",res_mat.max())
#             print('mean:',res_mat.mean())
#             print('std:',res_mat.std())
                
            fig = plt.figure()
            iax = fig.add_subplot(121)
            iax.imshow(show_mat,clim=(0,1),cmap='gray')
            iax2 = fig.add_subplot(122)
            iax2.imshow(res_mat,clim=(0,1),cmap='gray')
            plt.title('gamma = {}'.format(g))
            plt.show()
        
        
        clean_up_img(img)
    except Exception as e:
        clean_up_img(img)
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        print("{} in line {}".format(e,exc_tb.tb_lineno))
        traceback.print_tb(exc_tb)
        
        
        
def simple_test(img):

    try:

        print('Analyzing image: {}'.format(img.filepath))
        time.sleep(1)


        # image
        img.tempdir = tempfile.mkdtemp()
        print(img.tempdir)
        if img.img_data is None:
            img.load_image()

        # sum over time axis
        show_method = 'sum' if  is_pet(img.filepath) else 'max'
        ic = .93 if is_pet(img.filepath) else .97
        frame = img.collapse_over_frames(method='sum')
        show_frame = img.collapse_over_frames(method=show_method)


        # collapse on z axis
        axis = img.get_axis('z')
        mat = getattr(frame, show_method)(axis=axis)
        mat = normalize(mat)
        show_mat = getattr(show_frame, show_method)(axis=axis)
        show_mat = normalize(show_mat)

        # get hypothesis vars
        # assume mice compose top 10 %
        print(mat.mean(),mat.std())
        flt = mat.flatten()
        cutoff = np.percentile(flt,ic*100)

        mouse_pix = np.array([k for k in flt if k > cutoff])
        nothing_pix = np.array([k for k in flt if k < cutoff])

        h0 = nothing_pix.mean(), nothing_pix.std()**2
        h1 = mouse_pix.mean(), mouse_pix.std()**2




        gammas = [1,]
        for g in gammas:

            # hypothesis test each point is it a mouse?
            tf1 = lambda x: int(likelihood_point(x,h1=h1,h0=h0)>g)
            vf1 = np.vectorize(tf1)
            testmat1 = vf1(mat)
            res = vf1(mat)
            
            fig = plt.figure()
            iax = fig.add_subplot(121)
            iax.imshow(show_mat,clim=(0,1),cmap='gray')
            iax2 = fig.add_subplot(122)
            iax2.imshow(res,clim=(0,1),cmap='gray')
            plt.title('gamma = {}'.format(g))
            plt.show()
            
    except Exception as e:
        clean_up_img(img)
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        print("{} in line {}".format(e,exc_tb.tb_lineno))
        traceback.print_tb(exc_tb)

# %%
for pimg in pet_imgs:
    simple_test(pimg)
# Out:
# Analyzing image: C:\Users\jmusko01\Documents\mycode\old_preproc_work\data\pcds\Concorde Microsystems F220 Scanner\1 Bed\Static\mpet3681a_em1_v1.img
# C:\Users\jmusko01\AppData\Local\Temp\tmp_ph5riy7
# 0.020302111 0.10604329
# C:\Users\jmusko01\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: overflow encountered in exp
# Analyzing image: C:\Users\jmusko01\Documents\mycode\old_preproc_work\data\pcds\Concorde Microsystems F220 Scanner\1 Rat\Dynamic\mpet3659b_em1_v1.img
# C:\Users\jmusko01\AppData\Local\Temp\tmpep8_jgh3
# 0.011057703714521309 0.057476858637821135
# Analyzing image: C:\Users\jmusko01\Documents\mycode\old_preproc_work\data\pcds\Concorde Microsystems F220 Scanner\2 Bed\Dynamic\mpet3688a_em1_v1.img
# C:\Users\jmusko01\AppData\Local\Temp\tmp_sg0ez7e
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-181-1d15e5d9c85f> in <module>()
#       1 for pimg in pet_imgs:
# ----> 2     simple_test(pimg)
#
# <ipython-input-180-0396ad1de2bc> in simple_test(img)
#     393         ic = .93 if is_pet(img.filepath) else .999
#     394         frame = img.collapse_over_frames(method='sum')
# --> 395         show_frame = img.collapse_over_frames(method=show_method)
#     396
#     397
#
# ~\Documents\mycode\preprocessing\src\imgclasses\baseimage.py in collapse_over_frames(self, method, matrix)
#     539             matrix = self.img_data
#     540         self.check_collapse_method(method)
# --> 541         return getattr(self.img_data,method)(axis=3)
#     542
#     543     def rotate_on_axis(self, axis, log=False):
#
# ~\AppData\Roaming\Python\Python36\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 32     return umr_sum(a, axis, dtype, out, keepdims)
#      33
#      34 def _prod(a, axis=None, dtype=None, out=None, keepdims=False):
#
# KeyboardInterrupt:

# %%
for cimg in ct_imgs:
    simple_test(cimg)
# Out:
# Analyzing image: C:\Users\jmusko01\Documents\mycode\old_preproc_work\data\pcds\mpet3630\a\mpet3630a_ct1_v1.ct.img
# C:\Users\jmusko01\AppData\Local\Temp\tmpy2etqthh
# -0.029987156 0.05346732
# Analyzing image: C:\Users\jmusko01\Documents\mycode\old_preproc_work\data\pcds\mpet3630\b\mpet3630b_ct1_v1.ct.img
# C:\Users\jmusko01\AppData\Local\Temp\tmpvfjofbh_
# -0.023495754 0.050671868
# Analyzing image: C:\Users\jmusko01\Documents\mycode\old_preproc_work\data\pcds\output\mpet3739d_ct2_v1_s1.ct.img
# C:\Users\jmusko01\AppData\Local\Temp\tmp88d44mr2
# File dimensions: (320,640,928,1)
# Reading image data...
# [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\jmusko01\\AppData\\Local\\Temp\\tmp88d44mr2\\mpet3739d_ct2_v1_s1.dat'
# error when removing:
# C:\Users\jmusko01\AppData\Local\Temp\tmp88d44mr2
# unpack requires a buffer of 10000000 bytes in line 389
#   File "<ipython-input-183-b5ae094e4112>", line 389, in simple_test
#     img.load_image()
#   File "C:\Users\jmusko01\Documents\mycode\preprocessing\src\imgclasses\baseimage.py", line 322, in load_image
#     read_chunks(ifr)
#   File "C:\Users\jmusko01\Documents\mycode\preprocessing\src\imgclasses\baseimage.py", line 194, in read_chunks
#     chunk = np.array(struct.unpack(sf*npixels,img_file.read(nbytes)))
# Analyzing image: C:\Users\jmusko01\Documents\mycode\old_preproc_work\data\pcds\Seimens Inveon Scanner\1 Bed\Dynamic\CT\mpet3715b_ct1_v1.ct.img
# C:\Users\jmusko01\AppData\Local\Temp\tmpxr16baln
# -0.11398278 0.11928913
# Analyzing image: C:\Users\jmusko01\Documents\mycode\old_preproc_work\data\pcds\Seimens Inveon Scanner\1 Bed\Static\CT\mpet3631a_ct1_v1.ct.img
# C:\Users\jmusko01\AppData\Local\Temp\tmppisj1hxf
# -0.11562137 0.1041999
# Analyzing image: C:\Users\jmusko01\Documents\mycode\old_preproc_work\data\pcds\Seimens Inveon Scanner\1 Rat\Dynamic\CT\mpet3739a_ct1_v1.ct.img
# C:\Users\jmusko01\AppData\Local\Temp\tmp0kp55yyn
# -0.09975313 0.2265893
# Analyzing image: C:\Users\jmusko01\Documents\mycode\old_preproc_work\data\pcds\Seimens Inveon Scanner\1 Rat\Static\CT\mpet3617a_ct1_v1.ct.img
# C:\Users\jmusko01\AppData\Local\Temp\tmpcv_s52sc
# -0.090784244 0.21656783
# Analyzing image: C:\Users\jmusko01\Documents\mycode\old_preproc_work\data\pcds\Seimens Inveon Scanner\2 Bed\Dynamic\CT\mpet3741a_ct1_v1.ct.img
# C:\Users\jmusko01\AppData\Local\Temp\tmpijy7lnor
# File dimensions: (512,512,679,1)
# Reading image data...
# -0.09023572 0.15968943
# Analyzing image: C:\Users\jmusko01\Documents\mycode\old_preproc_work\data\pcds\Seimens Inveon Scanner\2 Bed\Static\CT\mpet3742a_ct1_v1.ct.img
# C:\Users\jmusko01\AppData\Local\Temp\tmpuboxf0tf
# File dimensions: (512,512,679,1)
# Reading image data...
# -0.094242126 0.14830709
# Analyzing image: C:\Users\jmusko01\Documents\mycode\old_preproc_work\data\pcds\Seimens Inveon Scanner\4 Bed\Dynamic\CT\mpet3721a_ct1_v1.ct.img
# C:\Users\jmusko01\AppData\Local\Temp\tmpey51uoe7
# File dimensions: (512,512,679,1)
# Reading image data...
# -0.022350252 0.06557673
# Analyzing image: C:\Users\jmusko01\Documents\mycode\old_preproc_work\data\pcds\Seimens Inveon Scanner\4 Bed\Static\CT\mpet3745a_ct1_v1.ct.img
# C:\Users\jmusko01\AppData\Local\Temp\tmprm8ivul5
# File dimensions: (512,512,679,1)
# Reading image data...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-186-ead45216bb33> in <module>()
#       1 for cimg in ct_imgs:
# ----> 2     simple_test(cimg)
#
# <ipython-input-183-b5ae094e4112> in simple_test(img)
#     387         print(img.tempdir)
#     388         if img.img_data is None:
# --> 389             img.load_image()
#     390
#     391         # sum over time axis
#
# ~\Documents\mycode\preprocessing\src\imgclasses\baseimage.py in load_image(self, plane_range, frame_range, unscaled)
#     320             fr_offset = ifr*(ps.x_dimension*ps.y_dimension*ps.z_dimension)
#     321             img_file.seek(bpp*(fr_offset+pl_offset))
# --> 322             read_chunks(ifr)
#     323         imgmat = imgmat.swapaxes(0,1)
#     324         img_file.close()
#
# ~\Documents\mycode\preprocessing\src\imgclasses\baseimage.py in read_chunks(ifr)
#     192                 nbytes = read_lim
#     193                 npixels = int(nbytes/bpp)
# --> 194                 chunk = np.array(struct.unpack(sf*npixels,img_file.read(nbytes)))
#     195                 imgmat[ifr][ix:ix+npixels] = chunk
#     196                 to_read -= read_lim
#
# KeyboardInterrupt:

# %%
for cimg in ct_imgs:
    circle_algo(cimg)
# Out:
# File dimensions: (512,512,679,1)
# Reading image data...
# Done loading...
# using cutoff: 0.9848586419468606
# (0.24104266, 0.003700664723806979) (-0.034237087, 0.0016928454729804449)
# -0.030053455 0.05345584
# removing tempdir C:\Users\jmusko01\AppData\Local\Temp\tmp2tmthfk7
# File dimensions: (512,512,679,1)
# Reading image data...
# Done loading...
# using cutoff: 0.9881940273575153
# (0.23787078, 0.004767517567927371) (-0.026604164, 0.001735918746588197)
# -0.023472564 0.050894383
# removing tempdir C:\Users\jmusko01\AppData\Local\Temp\tmpk64gd25j
# File dimensions: (320,640,928,1)
# Reading image data...
# [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\jmusko01\\AppData\\Local\\Temp\\tmph2gq9h_n\\mpet3739d_ct2_v1_s1.dat'
# error when removing:
# C:\Users\jmusko01\AppData\Local\Temp\tmph2gq9h_n
# unpack requires a buffer of 10000000 bytes in line 305
#   File "<ipython-input-167-0dc1d880d937>", line 305, in circle_algo
#     img.load_image()
#   File "C:\Users\jmusko01\Documents\mycode\preprocessing\src\imgclasses\baseimage.py", line 322, in load_image
#     read_chunks(ifr)
#   File "C:\Users\jmusko01\Documents\mycode\preprocessing\src\imgclasses\baseimage.py", line 194, in read_chunks
#     chunk = np.array(struct.unpack(sf*npixels,img_file.read(nbytes)))
# File dimensions: (512,512,679,1)
# Reading image data...
# Done loading...
# using cutoff: 0.9412797312581308
# (0.28675345, 0.06117896693144531) (-0.13902152, 0.0006929441612527065)
# -0.11399247 0.11944373
# C:\Users\jmusko01\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:285: RuntimeWarning: overflow encountered in exp
# removing tempdir C:\Users\jmusko01\AppData\Local\Temp\tmp8vh8ua19
# File dimensions: (512,512,679,1)
# Reading image data...
# Done loading...
# using cutoff: 0.9404780730954545
# (0.2241535, 0.054220725651732415) (-0.13702232, 0.0004029150234521328)
# -0.115500994 0.10444848
# removing tempdir C:\Users\jmusko01\AppData\Local\Temp\tmpnbuaf7ly
# File dimensions: (512,512,679,1)
# Reading image data...
# Done loading...
# using cutoff: 0.9487501526192905
# (0.5750133, 0.013737559013416112) (-0.1363441, 0.027353896377476872)
# -0.09987315 0.2264278
# removing tempdir C:\Users\jmusko01\AppData\Local\Temp\tmpw_byzirl
# File dimensions: (512,512,679,1)
# Reading image data...
# Done loading...
# using cutoff: 0.9533536902432228
# (0.56643176, 0.01039226914912561) (-0.12332268, 0.026368264517259377)
# -0.09111674 0.2163314
# removing tempdir C:\Users\jmusko01\AppData\Local\Temp\tmp8ob5mfe2
# File dimensions: (512,512,679,1)
# Reading image data...
# Done loading...
# using cutoff: 0.9537779103891165
# (0.5245727, 0.021404349235184306) (-0.12013486, 0.0063585690377703785)
# -0.0903077 0.15935746
# removing tempdir C:\Users\jmusko01\AppData\Local\Temp\tmpy8byon9u
# File dimensions: (512,512,679,1)
# Reading image data...
# Done loading...
# using cutoff: 0.9518178904027121
# (0.48993066, 0.022094476224412185) (-0.1236271, 0.0038894865221306696)
# -0.0940427 0.1484715
# removing tempdir C:\Users\jmusko01\AppData\Local\Temp\tmpajoyhcpy
# File dimensions: (512,512,679,1)
# Reading image data...
# Done loading...
# using cutoff: 0.9886795125415354
# (0.26008022, 0.0010028643426436418) (-0.025770945, 0.003349351763211106)
# -0.022512821 0.0651311
# removing tempdir C:\Users\jmusko01\AppData\Local\Temp\tmpns1bltpp
# File dimensions: (512,512,679,1)
# Reading image data...
# Done loading...
# using cutoff: 0.9734786742857056
# (0.52654773, 0.007231176139983697) (-0.068128094, 0.014187993322735404)
# -0.05233927 0.15212898
# removing tempdir C:\Users\jmusko01\AppData\Local\Temp\tmpjeifqt62
# File dimensions: (640,640,928,1)
# Reading image data...
# Done loading...
# using cutoff: 0.9943411850551952
# (0.5380575, 0.006564913696820662) (-0.014479966, 0.027188915618233445)
# -0.011285608 0.16977774
# removing tempdir C:\Users\jmusko01\AppData\Local\Temp\tmp3au1cj5b

# %%
tempfile.mkdtemp()
# Out:
# 'C:\\Users\\Jack\\AppData\\Local\\Temp\\tmpz9r5a2hr'
